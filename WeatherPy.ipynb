# %%
# import the dependencies 


import requests
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
from citipy import citipy

cities = []



for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
#   Import our dependencies and initialize counters and an empty list that will hold the weather data

import time 
from datetime import datetime 


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "b12d6f82a737d1ed5357caf690add7a6"

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging 

print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.

record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    
    
    # Add 1 to the record count.
    record_count += 1
    
                                            
   # Run an API request for each of the cities.


    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data. 
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the data to ISO standard 
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        
        # Append the city information into city_data list.
        
        city_data.append({"city": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity, 
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
                          
        
        
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | havoysund
# Processing Record 8 of Set 1 | sibu
# Processing Record 9 of Set 1 | tessalit
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | santo antonio do ica
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | sao jose da coroa grande
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | wucheng
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | buluang
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | cap malheureux
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | sorland
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | college
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | roma
# Processing Record 28 of Set 1 | marsa matruh
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | samarinda
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | caravelas
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | hofn
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | yumen
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | tilichiki
# Processing Record 42 of Set 1 | anadyr
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | jacksonville
# Processing Record 46 of Set 1 | marquard
# Processing Record 47 of Set 1 | kaposvar
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | xacmaz
# Processing Record 50 of Set 1 | cayenne
# Processing Record 1 of Set 2 | batticaloa
# Processing Record 2 of Set 2 | ranong
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | byron bay
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | magalia
# Processing Record 7 of Set 2 | kahului
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | ararat
# Processing Record 14 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | noyabrsk
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | hearst
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | esmeraldas
# Processing Record 21 of Set 2 | sistranda
# Processing Record 22 of Set 2 | kamina
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | leshukonskoye
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | trelew
# Processing Record 30 of Set 2 | brigg
# Processing Record 31 of Set 2 | pevek
# Processing Record 32 of Set 2 | chicama
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | dawei
# Processing Record 36 of Set 2 | chaman
# Processing Record 37 of Set 2 | port moresby
# Processing Record 38 of Set 2 | charters towers
# Processing Record 39 of Set 2 | colac
# Processing Record 40 of Set 2 | radchenko
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | xinxiang
# Processing Record 45 of Set 2 | dicabisagan
# Processing Record 46 of Set 2 | dire
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | hibbing
# Processing Record 49 of Set 2 | garden city
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | itarema
# Processing Record 2 of Set 3 | tiruvottiyur
# City not found. Skipping...
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | maicao
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | bo rai
# Processing Record 8 of Set 3 | yulara
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | mutsu
# Processing Record 12 of Set 3 | grande-riviere
# City not found. Skipping...
# Processing Record 13 of Set 3 | krasnyy chikoy
# Processing Record 14 of Set 3 | fayaoue
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | dubrovnik
# Processing Record 20 of Set 3 | coihaique
# Processing Record 21 of Set 3 | poum
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | northam
# Processing Record 24 of Set 3 | hermosillo
# Processing Record 25 of Set 3 | simpang
# Processing Record 26 of Set 3 | hambantota
# Processing Record 27 of Set 3 | gimli
# Processing Record 28 of Set 3 | bolama
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | beringovskiy
# Processing Record 31 of Set 3 | kirakira
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | gigmoto
# Processing Record 34 of Set 3 | charagua
# Processing Record 35 of Set 3 | moose factory
# Processing Record 36 of Set 3 | chiang khong
# Processing Record 37 of Set 3 | gizo
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | fort smith
# Processing Record 40 of Set 3 | urumqi
# Processing Record 41 of Set 3 | yaroslavl
# Processing Record 42 of Set 3 | yar-sale
# Processing Record 43 of Set 3 | kaitangata
# Processing Record 44 of Set 3 | kuna
# Processing Record 45 of Set 3 | filadelfia
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | evensk
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | flinders
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | madison
# Processing Record 5 of Set 4 | terrace
# Processing Record 6 of Set 4 | hamilton
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | bara
# Processing Record 9 of Set 4 | dongsheng
# Processing Record 10 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 4 | antofagasta
# Processing Record 12 of Set 4 | saskylakh
# Processing Record 13 of Set 4 | san isidro
# Processing Record 14 of Set 4 | siyabuswa
# Processing Record 15 of Set 4 | odessa
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | okato
# Processing Record 18 of Set 4 | tungor
# Processing Record 19 of Set 4 | tatarsk
# Processing Record 20 of Set 4 | prainha
# Processing Record 21 of Set 4 | kuah
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | kiama
# Processing Record 24 of Set 4 | saint anthony
# Processing Record 25 of Set 4 | koutsouras
# Processing Record 26 of Set 4 | jiuquan
# Processing Record 27 of Set 4 | pemangkat
# Processing Record 28 of Set 4 | lagunas
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | mayumba
# Processing Record 32 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | klaksvik
# Processing Record 35 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 4 | hualmay
# Processing Record 37 of Set 4 | magadan
# Processing Record 38 of Set 4 | shingu
# Processing Record 39 of Set 4 | mildura
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | marawi
# Processing Record 42 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 43 of Set 4 | wanning
# Processing Record 44 of Set 4 | vao
# Processing Record 45 of Set 4 | jablah
# Processing Record 46 of Set 4 | maneadero
# Processing Record 47 of Set 4 | nouadhibou
# Processing Record 48 of Set 4 | krasnovishersk
# Processing Record 49 of Set 4 | san jose
# Processing Record 50 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 5 | safaga
# Processing Record 2 of Set 5 | laguna
# Processing Record 3 of Set 5 | teeli
# Processing Record 4 of Set 5 | birin
# Processing Record 5 of Set 5 | tombouctou
# Processing Record 6 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | ankazoabo
# Processing Record 9 of Set 5 | stephenville
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | huarmey
# Processing Record 12 of Set 5 | bilma
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | mingguang
# Processing Record 15 of Set 5 | veraval
# Processing Record 16 of Set 5 | okha
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | yartsevo
# Processing Record 19 of Set 5 | shawnee
# Processing Record 20 of Set 5 | necochea
# Processing Record 21 of Set 5 | lima
# Processing Record 22 of Set 5 | luangwa
# Processing Record 23 of Set 5 | erenhot
# Processing Record 24 of Set 5 | panzhihua
# Processing Record 25 of Set 5 | vuktyl
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | saint-joseph
# Processing Record 28 of Set 5 | kommunar
# Processing Record 29 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 5 | santander
# Processing Record 31 of Set 5 | merin
# Processing Record 32 of Set 5 | baryatino
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | takoradi
# Processing Record 35 of Set 5 | egvekinot
# Processing Record 36 of Set 5 | alekseyevsk
# Processing Record 37 of Set 5 | poli
# Processing Record 38 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 5 | portland
# Processing Record 40 of Set 5 | syamzha
# Processing Record 41 of Set 5 | vieques
# Processing Record 42 of Set 5 | bojnurd
# Processing Record 43 of Set 5 | sao filipe
# Processing Record 44 of Set 5 | pasni
# Processing Record 45 of Set 5 | novouzensk
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 5 | xuddur
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 6 | port-gentil
# Processing Record 2 of Set 6 | alekseyevka
# Processing Record 3 of Set 6 | lerwick
# Processing Record 4 of Set 6 | jinka
# Processing Record 5 of Set 6 | adrar
# Processing Record 6 of Set 6 | namatanai
# Processing Record 7 of Set 6 | airai
# Processing Record 8 of Set 6 | beira
# Processing Record 9 of Set 6 | puerto escondido
# Processing Record 10 of Set 6 | rudsar
# Processing Record 11 of Set 6 | hurghada
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | dedougou
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | taltal
# Processing Record 16 of Set 6 | kavaratti
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | ambilobe
# Processing Record 19 of Set 6 | floresta
# Processing Record 20 of Set 6 | narsaq
# Processing Record 21 of Set 6 | kutum
# Processing Record 22 of Set 6 | the pas
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | am timan
# Processing Record 25 of Set 6 | zomin
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | aitape
# Processing Record 28 of Set 6 | surt
# Processing Record 29 of Set 6 | oranjemund
# Processing Record 30 of Set 6 | ixtapa
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | zuya
# Processing Record 33 of Set 6 | yelizovo
# Processing Record 34 of Set 6 | sobolevo
# Processing Record 35 of Set 6 | lavrentiya
# Processing Record 36 of Set 6 | asfi
# Processing Record 37 of Set 6 | soto la marina
# Processing Record 38 of Set 6 | rudbar
# Processing Record 39 of Set 6 | batagay
# Processing Record 40 of Set 6 | viedma
# Processing Record 41 of Set 6 | sokoni
# Processing Record 42 of Set 6 | port shepstone
# Processing Record 43 of Set 6 | pringsewu
# Processing Record 44 of Set 6 | acapulco
# Processing Record 45 of Set 6 | paranaiba
# Processing Record 46 of Set 6 | xining
# Processing Record 47 of Set 6 | chivilcoy
# Processing Record 48 of Set 6 | tuy hoa
# Processing Record 49 of Set 6 | funtua
# Processing Record 50 of Set 6 | lusaka
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | hokitika
# Processing Record 3 of Set 7 | salalah
# Processing Record 4 of Set 7 | dwarka
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | tyukhtet
# Processing Record 7 of Set 7 | ilulissat
# Processing Record 8 of Set 7 | havre-saint-pierre
# Processing Record 9 of Set 7 | bryan
# Processing Record 10 of Set 7 | robat karim
# Processing Record 11 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 12 of Set 7 | gat
# Processing Record 13 of Set 7 | tautira
# Processing Record 14 of Set 7 | chadiza
# Processing Record 15 of Set 7 | sao joao da barra
# Processing Record 16 of Set 7 | brattleboro
# Processing Record 17 of Set 7 | hirara
# Processing Record 18 of Set 7 | petukhovo
# Processing Record 19 of Set 7 | general roca
# Processing Record 20 of Set 7 | itaueira
# Processing Record 21 of Set 7 | cepelare
# Processing Record 22 of Set 7 | olafsvik
# Processing Record 23 of Set 7 | dumas
# Processing Record 24 of Set 7 | batagay-alyta
# Processing Record 25 of Set 7 | derzhavinsk
# Processing Record 26 of Set 7 | luderitz
# Processing Record 27 of Set 7 | puerto cortes
# City not found. Skipping...
# Processing Record 28 of Set 7 | pangnirtung
# Processing Record 29 of Set 7 | lazaro cardenas
# Processing Record 30 of Set 7 | chrastava
# Processing Record 31 of Set 7 | san patricio
# Processing Record 32 of Set 7 | vila velha
# Processing Record 33 of Set 7 | turayf
# Processing Record 34 of Set 7 | aosta
# Processing Record 35 of Set 7 | iskateley
# Processing Record 36 of Set 7 | ituporanga
# Processing Record 37 of Set 7 | rath
# Processing Record 38 of Set 7 | geraldton
# Processing Record 39 of Set 7 | bayshore gardens
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | taoudenni
# Processing Record 42 of Set 7 | martapura
# Processing Record 43 of Set 7 | cascais
# Processing Record 44 of Set 7 | komsomolskiy
# Processing Record 45 of Set 7 | sohag
# Processing Record 46 of Set 7 | chokurdakh
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | kropotkin
# Processing Record 49 of Set 7 | mehamn
# Processing Record 50 of Set 7 | qasigiannguit
# Processing Record 1 of Set 8 | tiarei
# Processing Record 2 of Set 8 | chapais
# Processing Record 3 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 8 | tarquinia
# Processing Record 5 of Set 8 | coleraine
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | aklavik
# Processing Record 9 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 8 | anaco
# Processing Record 11 of Set 8 | saint-augustin
# Processing Record 12 of Set 8 | mount vernon
# Processing Record 13 of Set 8 | sambava
# Processing Record 14 of Set 8 | constitucion
# Processing Record 15 of Set 8 | yomou
# Processing Record 16 of Set 8 | kjollefjord
# Processing Record 17 of Set 8 | saint-georges
# Processing Record 18 of Set 8 | caraballeda
# Processing Record 19 of Set 8 | zhetysay
# Processing Record 20 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 8 | longyearbyen
# Processing Record 22 of Set 8 | ormond beach
# Processing Record 23 of Set 8 | fortuna
# Processing Record 24 of Set 8 | thyboron
# Processing Record 25 of Set 8 | sola
# Processing Record 26 of Set 8 | itaituba
# Processing Record 27 of Set 8 | linkoping
# Processing Record 28 of Set 8 | ust-tsilma
# Processing Record 29 of Set 8 | alofi
# Processing Record 30 of Set 8 | sangar
# Processing Record 31 of Set 8 | kamarion
# Processing Record 32 of Set 8 | otradnoye
# Processing Record 33 of Set 8 | ridgecrest
# Processing Record 34 of Set 8 | litovko
# Processing Record 35 of Set 8 | bet shemesh
# Processing Record 36 of Set 8 | norman wells
# Processing Record 37 of Set 8 | balabac
# Processing Record 38 of Set 8 | faya
# Processing Record 39 of Set 8 | skibbereen
# Processing Record 40 of Set 8 | port macquarie
# Processing Record 41 of Set 8 | cairns
# Processing Record 42 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 8 | wer
# Processing Record 44 of Set 8 | sumbe
# Processing Record 45 of Set 8 | caucaia
# Processing Record 46 of Set 8 | ndele
# Processing Record 47 of Set 8 | barahona
# Processing Record 48 of Set 8 | todos santos
# Processing Record 49 of Set 8 | linjiang
# Processing Record 50 of Set 8 | fort nelson
# Processing Record 1 of Set 9 | burnie
# Processing Record 2 of Set 9 | cabatuan
# Processing Record 3 of Set 9 | ahipara
# Processing Record 4 of Set 9 | cidreira
# Processing Record 5 of Set 9 | keuruu
# Processing Record 6 of Set 9 | usogorsk
# Processing Record 7 of Set 9 | lagoa
# Processing Record 8 of Set 9 | maple creek
# Processing Record 9 of Set 9 | ayan
# Processing Record 10 of Set 9 | houma
# Processing Record 11 of Set 9 | broome
# Processing Record 12 of Set 9 | chabua
# Processing Record 13 of Set 9 | acarau
# Processing Record 14 of Set 9 | bogorodskoye
# Processing Record 15 of Set 9 | caceres
# Processing Record 16 of Set 9 | kljajicevo
# Processing Record 17 of Set 9 | garm
# City not found. Skipping...
# Processing Record 18 of Set 9 | sakakah
# Processing Record 19 of Set 9 | spassk-ryazanskiy
# Processing Record 20 of Set 9 | san cristobal
# Processing Record 21 of Set 9 | chabahar
# Processing Record 22 of Set 9 | ust-nera
# Processing Record 23 of Set 9 | westport
# Processing Record 24 of Set 9 | beloha
# Processing Record 25 of Set 9 | maniitsoq
# Processing Record 26 of Set 9 | padang
# Processing Record 27 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 28 of Set 9 | coahuayana
# Processing Record 29 of Set 9 | severo-kurilsk
# Processing Record 30 of Set 9 | arauco
# Processing Record 31 of Set 9 | katsuura
# Processing Record 32 of Set 9 | kieta
# Processing Record 33 of Set 9 | porbandar
# Processing Record 34 of Set 9 | chernyshevskiy
# Processing Record 35 of Set 9 | bintulu
# Processing Record 36 of Set 9 | benghazi
# Processing Record 37 of Set 9 | honiara
# Processing Record 38 of Set 9 | iqaluit
# Processing Record 39 of Set 9 | srednekolymsk
# Processing Record 40 of Set 9 | mount isa
# Processing Record 41 of Set 9 | castro
# Processing Record 42 of Set 9 | talnakh
# Processing Record 43 of Set 9 | shimoda
# Processing Record 44 of Set 9 | melfi
# Processing Record 45 of Set 9 | huilong
# Processing Record 46 of Set 9 | murray bridge
# Processing Record 47 of Set 9 | inzer
# Processing Record 48 of Set 9 | kendari
# Processing Record 49 of Set 9 | longyan
# Processing Record 50 of Set 9 | thai binh
# Processing Record 1 of Set 10 | poya
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | pahrump
# Processing Record 4 of Set 10 | tagusao
# Processing Record 5 of Set 10 | codrington
# Processing Record 6 of Set 10 | nizhniy tsasuchey
# Processing Record 7 of Set 10 | candido mendes
# Processing Record 8 of Set 10 | eureka
# Processing Record 9 of Set 10 | zhenjiang
# Processing Record 10 of Set 10 | neiafu
# Processing Record 11 of Set 10 | kidderminster
# Processing Record 12 of Set 10 | aykhal
# Processing Record 13 of Set 10 | saurimo
# Processing Record 14 of Set 10 | nantucket
# Processing Record 15 of Set 10 | kaka
# Processing Record 16 of Set 10 | betioky
# Processing Record 17 of Set 10 | cockburn town
# Processing Record 18 of Set 10 | marfino
# Processing Record 19 of Set 10 | buchanan
# Processing Record 20 of Set 10 | ternate
# Processing Record 21 of Set 10 | la tuque
# Processing Record 22 of Set 10 | xiaoweizhai
# Processing Record 23 of Set 10 | saint-paul
# Processing Record 24 of Set 10 | coxim
# Processing Record 25 of Set 10 | marystown
# Processing Record 26 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 10 | santa cruz de tenerife
# Processing Record 28 of Set 10 | sao francisco do sul
# Processing Record 29 of Set 10 | butiama
# Processing Record 30 of Set 10 | clarence town
# Processing Record 31 of Set 10 | kulhudhuffushi
# Processing Record 32 of Set 10 | verkhniy fiagdon
# Processing Record 33 of Set 10 | port hardy
# Processing Record 34 of Set 10 | kruisfontein
# Processing Record 35 of Set 10 | sabang
# Processing Record 36 of Set 10 | karakol
# Processing Record 37 of Set 10 | ochakiv
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | bobonong
# City not found. Skipping...
# Processing Record 40 of Set 10 | kurchum
# Processing Record 41 of Set 10 | caluquembe
# Processing Record 42 of Set 10 | tucumcari
# Processing Record 43 of Set 10 | vero beach
# Processing Record 44 of Set 10 | harrisonville
# Processing Record 45 of Set 10 | innisfail
# Processing Record 46 of Set 10 | serenje
# Processing Record 47 of Set 10 | ajaccio
# Processing Record 48 of Set 10 | kobelyaky
# Processing Record 49 of Set 10 | tuatapere
# Processing Record 50 of Set 10 | murovane
# Processing Record 1 of Set 11 | mamallapuram
# Processing Record 2 of Set 11 | vestmanna
# Processing Record 3 of Set 11 | cabedelo
# Processing Record 4 of Set 11 | ginda
# Processing Record 5 of Set 11 | maceio
# Processing Record 6 of Set 11 | broken hill
# Processing Record 7 of Set 11 | henzada
# City not found. Skipping...
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 11 | san lorenzo
# Processing Record 11 of Set 11 | satna
# Processing Record 12 of Set 11 | kodinsk
# Processing Record 13 of Set 11 | vila franca do campo
# Processing Record 14 of Set 11 | ampanihy
# Processing Record 15 of Set 11 | macusani
# Processing Record 16 of Set 11 | baruun-urt
# Processing Record 17 of Set 11 | ambon
# Processing Record 18 of Set 11 | christchurch
# Processing Record 19 of Set 11 | luchegorsk
# Processing Record 20 of Set 11 | tyrma
# Processing Record 21 of Set 11 | coari
# Processing Record 22 of Set 11 | mahajanga
# Processing Record 23 of Set 11 | porto novo
# Processing Record 24 of Set 11 | eyl
# Processing Record 25 of Set 11 | nishihara
# Processing Record 26 of Set 11 | liwale
# Processing Record 27 of Set 11 | muros
# Processing Record 28 of Set 11 | nome
# Processing Record 29 of Set 11 | lae
# Processing Record 30 of Set 11 | bilibino
# Processing Record 31 of Set 11 | husavik
# Processing Record 32 of Set 11 | zhenhai
# Processing Record 33 of Set 11 | ucluelet
# Processing Record 34 of Set 11 | san ramon
# Processing Record 35 of Set 11 | abu dhabi
# Processing Record 36 of Set 11 | ban mo
# Processing Record 37 of Set 11 | marsh harbour
# Processing Record 38 of Set 11 | lasa
# Processing Record 39 of Set 11 | uvira
# Processing Record 40 of Set 11 | erzin
# Processing Record 41 of Set 11 | sorong
# Processing Record 42 of Set 11 | jabinyanah
# Processing Record 43 of Set 11 | ilhabela
# Processing Record 44 of Set 11 | teya
# Processing Record 45 of Set 11 | haapiti
# Processing Record 46 of Set 11 | telde
# Processing Record 47 of Set 11 | namibe
# Processing Record 48 of Set 11 | grand falls
# Processing Record 49 of Set 11 | axixa do tocantins
# City not found. Skipping...
# Processing Record 50 of Set 11 | tahoua
# Processing Record 1 of Set 12 | aberdeen
# Processing Record 2 of Set 12 | baghmara
# Processing Record 3 of Set 12 | russkaya polyana
# Processing Record 4 of Set 12 | vanimo
# Processing Record 5 of Set 12 | pakxan
# Processing Record 6 of Set 12 | troitsk
# Processing Record 7 of Set 12 | sioux lookout
# Processing Record 8 of Set 12 | pangkalanbuun
# Processing Record 9 of Set 12 | sweetwater
# Processing Record 10 of Set 12 | pompeu
# Processing Record 11 of Set 12 | porto franco
# Processing Record 12 of Set 12 | reforma
# Processing Record 13 of Set 12 | batemans bay
# Processing Record 14 of Set 12 | shirpur
# Processing Record 15 of Set 12 | nelson bay
# Processing Record 16 of Set 12 | ouallam
# Processing Record 17 of Set 12 | rocha
# Processing Record 18 of Set 12 | baie-comeau
# Processing Record 19 of Set 12 | mutoko
# Processing Record 20 of Set 12 | cheremukhovo
# Processing Record 21 of Set 12 | vostok
# Processing Record 22 of Set 12 | srandakan
# Processing Record 23 of Set 12 | elat
# Processing Record 24 of Set 12 | inirida
# Processing Record 25 of Set 12 | huejuquilla el alto
# Processing Record 26 of Set 12 | ariguani
# Processing Record 27 of Set 12 | lambarene
# Processing Record 28 of Set 12 | ossora
# Processing Record 29 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 12 | mubende
# Processing Record 31 of Set 12 | rafaela
# Processing Record 32 of Set 12 | salinas
# Processing Record 33 of Set 12 | alta floresta
# Processing Record 34 of Set 12 | buala
# Processing Record 35 of Set 12 | takapau
# Processing Record 36 of Set 12 | honningsvag
# Processing Record 37 of Set 12 | kahama
# Processing Record 38 of Set 12 | zonguldak
# Processing Record 39 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 12 | teahupoo
# Processing Record 41 of Set 12 | tongchuan
# Processing Record 42 of Set 12 | senanga
# Processing Record 43 of Set 12 | bereda
# Processing Record 44 of Set 12 | siniscola
# Processing Record 45 of Set 12 | black river
# Processing Record 46 of Set 12 | igrim
# Processing Record 47 of Set 12 | henties bay
# Processing Record 48 of Set 12 | dongying
# Processing Record 49 of Set 12 | saint-pierre
# Processing Record 50 of Set 12 | belyy yar
# Processing Record 1 of Set 13 | urengoy
# Processing Record 2 of Set 13 | qostanay
# Processing Record 3 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 13 | chipata
# Processing Record 5 of Set 13 | gunjur
# Processing Record 6 of Set 13 | banda aceh
# Processing Record 7 of Set 13 | tocopilla
# Processing Record 8 of Set 13 | caronport
# Processing Record 9 of Set 13 | puerto leguizamo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bredasdorp -34.5322   20.0403     65.75        78          96
# 1              Hermanus -34.4187   19.2345     65.39        76          82
# 2            Butaritari   3.0707  172.7902     81.21        78          44
# 3            Georgetown   5.4112  100.3354     78.75        93          40
# 4               Rikitea -23.1203 -134.9692     79.18        69           5
# 5             Havoysund  70.9963   24.6622     30.43        68         100
# 6                  Sibu   2.3000  111.8167     75.51       100          40
# 7              Tessalit  20.1986    1.0114     82.63         6          14
# 8             Jamestown  42.0970  -79.2353     65.52        35           0
# 9  Santo Antonio Do Ica  -3.1022  -67.9397     78.75        89          99
#
#    Wind Speed Country                 Date
# 0        2.86      ZA  2022-04-12 21:44:00
# 1        3.20      ZA  2022-04-12 21:42:53
# 2       16.46      KI  2022-04-12 21:46:43
# 3        3.44      MY  2022-04-12 21:42:37
# 4       16.71      PF  2022-04-12 21:42:44
# 5       13.65      NO  2022-04-12 21:46:44
# 6        3.44      MY  2022-04-12 21:46:44
# 7        9.22      ML  2022-04-12 21:46:45
# 8        3.00      US  2022-04-12 21:42:01
# 9        2.77      BR  2022-04-12 21:46:45

# %%
# Create the output file (CSV).

output_data_file = "weather_data/cities.csv"

# export the city_data into a CSV


city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract the relevant fields from the DataFrame to begin Plotting 

lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.



import time 

# Get todays date in seconds.
today = time.strftime("%x")
today
# Out:
# '04/12/22'

# %%
# import time module 


import time 


# Build scatterplots for latitude vs longitude 

plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label=("Cities")
# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+time.strftime("%x"))            
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
                     
# Save the figure

plt.savefig("weather_data/Fig1.png")
                      
# Show the Plot 
                    
plt.show()
# Out:
#   File "C:\Users\rhutc\AppData\Local\Temp\ipykernel_12420\130725532.py", line 14
#     plt.title(f"City Latitude vs. Max Temperature "+time.strftime("%x"))
#       ^
# SyntaxError: invalid syntax

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity 
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.



plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")



# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)



# Save the figure

plt.savefig("weather_data/Fig3.png")

# show plot

plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.


plt.scatter(lats,
           wind_speed,
           edgecolors="black", linewidths=1, maker"o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.


plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.

plt.savefig("weather_data\Fig")
